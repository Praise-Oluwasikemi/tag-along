# %%
def Square (x):
  result = x * x;
  return result

# %%
Square (8)
# Out:
# 64

# %%
# !pip install pandas

# %%
import pandas

# %%
import pandas as pd
days = pd.Series (['Monday', 'Tuesdy', 'Wednesday'])
print(days)
# Out:
# 0       Monday
# 1       Tuesdy
# 2    Wednesday
# dtype: object

# %%
pip install numpy

# %%
import numpy as np

days_list = np.array(['Monday', 'Tuesdy', 'Wednesday'])
numpy_days = pd.Series(days_list)
print(numpy_days)
# Out:
# 0       Monday
# 1       Tuesdy
# 2    Wednesday
# dtype: object

# %%
days = pd.Series(['Monday', 'Tuesdy', 'Wednesday'])
index=['a', 'b', 'c']
print(days)
# Out:
# 0       Monday
# 1       Tuesdy
# 2    Wednesday
# dtype: object

# %%
days1 = pd.Series ({'a': 'Monday', 'b': 'Tuesday', 'c': 'Wednesday'})
print(days1)
# Out:
# a       Monday
# b      Tuesday
# c    Wednesday
# dtype: object

# %%
print(pd.DataFrame)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_dict = {'country': ['Ghana', 'Kenya', 'Nigeria', 'Togo'], 'Capital' : [ 'Accra', 'Nairobi', 'Abuja', 'Lome'], 'Population' : [ 10000, 8500, 35000, 12000], 'Age' : [60, 10,80,75]}
df= pd.DataFrame(df_dict, index=[2, 2, 6, 8])
print(df)
# Out:
#    country  Capital  Population  Age
# 2    Ghana    Accra       10000   60
# 2    Kenya  Nairobi        8500   10
# 6  Nigeria    Abuja       35000   80
# 8     Togo     Lome       12000   75

# %%
df_list = [['Ghana', 'Accra', 10000, 60], ['Kenya', 'Nairobi', 8500, 10], ['Nigeria', 'Abuja', 35000, 80], ['Togo', 'Lome', 12000, 75]]
df1 = pd.DataFrame(df_list, columns=['Country', 'Capital', 'Population', 'Age'], index=[2, 4, 6,8])

# %%
print(df1)
# Out:
#    Country  Capital  Population  Age
# 2    Ghana    Accra       10000   60
# 4    Kenya  Nairobi        8500   10
# 6  Nigeria    Abuja       35000   80
# 8     Togo     Lome       12000   75

# %%
df.iloc[3]
# Out:
# country        Togo
# Capital        Lome
# Population    12000
# Age              75
# Name: 8, dtype: object

# %%
df.loc[6]
# Out:
# country       Nigeria
# Capital         Abuja
# Population      35000
# Age                80
# Name: 6, dtype: object

# %%
df['Capital']
# Out:
# 2      Accra
# 2    Nairobi
# 6      Abuja
# 8       Lome
# Name: Capital, dtype: object

# %%
df.at[6, 'country']
# Out:
# 'Nigeria'

# %%
df['Population'].sum()
# Out:
# 65500

# %%
df.describe()
# Out:
#          Population        Age
# count      4.000000   4.000000
# mean   16375.000000  56.250000
# std    12499.166639  31.983068
# min     8500.000000  10.000000
# 25%     9625.000000  47.500000
# 50%    11000.000000  67.500000
# 75%    17750.000000  76.250000
# max    35000.000000  80.000000

# %%
df_dict2 = {'Name' : ['James', 'Yemen', 'Caro', np.nan],
            'Profession' : ['Researvher', 'Arist', 'Doctor', 'Writer'],
            'Experience' : [12, np.nan, 10, 8],
            'Height' : [np.nan, 175, 180, 150]}

# %%
new_df = pd.DataFrame(df_dict2)

# %%
print(new_df)
# Out:
#     Name  Profession  Experience  Height
# 0  James  Researvher        12.0     NaN
# 1  Yemen       Arist         NaN   175.0
# 2   Caro      Doctor        10.0   180.0
# 3    NaN      Writer         8.0   150.0

# %%
new_df.isnull()
# Out:
#     Name  Profession  Experience  Height
# 0  False       False       False    True
# 1  False       False        True   False
# 2  False       False       False   False
# 3   True       False       False   False

# %%
import pandas as pd

csv_df = pd.read_csv('sample_file.csv')
csv_df.to_csv('sample_file.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-154-56b511b6da2b> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 csv_df = pd.read_csv('sample_file.csv')
#       4 csv_df.to_csv('sample_file.csv', index=False)
#
# ...

# %%
pip install xlrd

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({
    'unit': ['BBL', 'GAL', 'GRAMSU', 'KGU', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
    'count': [7998, 84, 464, 110, 11354, 180, 95, 100]
})

import seaborn as sns

sns.barplot(data=fuel_unit, x='unit', y='count',)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')
